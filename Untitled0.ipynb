# %% [markdown]
# **Data Types**

# %%
name="Sanjana"
print(type(name))
# Out:
# <class 'str'>

# %%
num1=69
num2=56.89
num3=4j
num4=-99
print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'int'>

# %% [markdown]
# ***Sequence data types***

# %%
lis=['san','123','30.45']
type(lis)
# Out:
# list

# %%
print(lis)
# Out:
# ['san', '123', '30.45']

# %%
lis2= ['apple','200','India','apple']
print(len(lis))
print(len(lis2))
lis3= lis+ lis2
print(lis3)
print(len(lis3))
# Out:
# 3
# 4
# ['san', '123', '30.45', 'apple', '200', 'India', 'apple']
# 7

# %%
lis2.append("Hubli")

# %%
lis2
