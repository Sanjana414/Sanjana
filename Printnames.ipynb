# %% [markdown]
# # ***My First Program***

# %%
print("I am Sanjna")
# Out:
# I am Sanjna

# %%
a+b

# %% [markdown]
# ***variable Declaration in Python***
#
# Rule1: variables should always start with an alphabet or _
# Rule2: variable should not start with some number or special characters Ex: 1stnum=5
# Rule3: variable declaration is case sensitive

# %%
a=5
b=9
sum=a+b
print(sum)
print("sum")
# Out:
# 14
# sum

# %% [markdown]
# **substraction**

# %%
a=6
b=3
diff=a-b
print(diff)
print("diff")
# Out:
# 3
# diff

# %% [markdown]
# **multiplication**

# %%
a=4
b=2
product=a*b
print(product)
print("product")
# Out:
# 8
# product

# %% [markdown]
# ***Division***

# %%
a=6
b=2
quo=a/b
rem=a%b
print(divi)
print(rem)
# Out:
# 3.0
# 0

# %% [markdown]
# ***squaring of numbers***

# %%
a=4
squ=a*a
print(squ)
# Out:
# 16

# %% [markdown]
# ***square root of a number***

# %%
import math
a=25
math.sqrt(a)
# Out:
# 5.0

# %% [markdown]
# ***sum of two numbers***

# %%
a=2
b=8
sum=a+b
print(sum)
# Out:
# 10
